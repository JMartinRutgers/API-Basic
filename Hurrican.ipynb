# %% [markdown]
# <a href="https://colab.research.google.com/github/JMartinRutgers/API-Basic/blob/main/Hurrican.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# pip install 
# !pip install cartopy

# %%
import gzip
import pandas as pd 
import matplotlib.pyplot as plt 
# %matplotlib inline

# %%
with gzip.open('/content/aal012021.dat.gz','r') as f: 
     forecast_columns = ['Basin', 'Clyclone', 'WarnDT', 'Model','Forecast_hour', 'Lat', 'Lon']
     df = pd.read_csv(f, header=None, index_col=False, 
                      names=forecast_columns,
                      usecols=[0, 1, 2, 3, 4, 5, 6])

# %% [markdown]
# # New Section

# %%
df.head()
df.tail()
# Out:
#       Basin  Clyclone      WarnDT  Model Forecast_hour  Lat    Lon
# 13988    AL         1  2021052400      3          XTRP  120   515N
# 13989    AL         1  2021052400      3          XTRP  132   530N
# 13990    AL         1  2021052400      3          XTRP  144   544N
# 13991    AL         1  2021052400      3          XTRP  156   558N
# 13992    AL         1  2021052400      3          XTRP  168   572N

# %%
#import plotly.express as px

#fig = px.scatter_geo(df, lat='Model',  lon='Lat' )
#fig.show()



import plotly.express as px
import matplotlib.pyplot as plt
from matplotlib.animation import FuncAnimation
import random

lat= []
lon= []

# index = count()

plt = px.scatter_geo(df, lat='Model', lon='Lat')
 

def animate(i):
    lat.append(next(lon))
    lon.append(ramdom.randit(0,10))
    
    plt.plot=(lat, lon)

    ani = FuncAnimation(plt.gcf(), animate, interval=100000)
     
plt.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="de6c82d1-c5ea-45ce-9619-81caf11eeaf1" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("de6c82d1-c5ea-45ce-9619-81caf11eeaf1")) {
#                     Plotly.newPlot(
#                         'de6c82d1-c5ea-45ce-9619-81caf11eeaf1',
# ...

# %%
def lat_lon_to_float(values):
 """
 convert NHC strings to floating point lat/lons.
 """
 result = []
 for v in values:
   if (v[-1] == 'S') or (v[-1] == 'W'):
     divisor = -10
   else:
       divisor = 10
       result.append(int(v[:-1]) /divisor)
 return result

# %%
lat_lon_to_float(['10N', '10S','10E','10W'])

import plotly.express as px
df.head


fig = px.scatter_geo(df, lat='Model',  lon='Lat' )
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="1c89a89d-863a-400a-b36f-c626514ceb90" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("1c89a89d-863a-400a-b36f-c626514ceb90")) {
#                     Plotly.newPlot(
#                         '1c89a89d-863a-400a-b36f-c626514ceb90',
# ...

# %%
df['Lat'] = lat_lon_to_float =(df['Lat'])
df['Lon'] = lat_lon_to_float =(df['Lon'])

# %%
df['Lon'].unique()
# Out:
# array([' 300N', ' 299N', ' 304N', ' 324N', ' 339N', ' 349N', ' 354N',
#        ' 350N', ' 345N', ' 343N', ' 344N', ' 357N', ' 360N', ' 368N',
#        ' 378N', ' 388N', ' 402N', ' 432N', ' 479N', ' 498N', ' 515N',
#        ' 541N', ' 570N', ' 591N', ' 602N', ' 609N', ' 617N', ' 624N',
#        ' 305N', ' 326N', ' 337N', ' 348N', ' 336N', ' 333N', ' 334N',
#        ' 353N', ' 371N', ' 400N', ' 439N', ' 311N', ' 310N', ' 325N',
#        ' 342N', ' 362N', ' 355N', ' 335N', ' 338N', ' 341N', ' 372N',
#        ' 384N', ' 398N', ' 412N', ' 431N', ' 449N', ' 463N', ' 472N',
#        ' 486N', ' 492N', ' 352N', ' 346N', ' 340N', ' 347N', ' 356N',
#        ' 364N', ' 395N', ' 417N', ' 440N', ' 460N', ' 482N', ' 504N',
#        ' 323N', ' 361N', ' 330N', ' 327N', ' 331N', ' 332N', ' 329N',
#        ' 321N', ' 328N', ' 382N', ' 409N', ' 420N', ' 437N', ' 450N',
#        ' 313N', ' 359N', ' 366N', ' 370N', ' 309N', ' 363N', ' 351N',
# ...

# %%
import cartopy.crs as ccrs
import cartopy.feature as cfeature
import matplotlib.pyplot as plt
import plotly.express as px
import pandas as pd 

colors =plt.rcParams['axes.prop_cycle'].by_key()['color']
model_colors={}

# for i, model in enumerate(df['Model'].unique()):
#    model_colors[model]= colors[i%10]


map_crs = ccrs.LambertConformal(central_latitude =45, central_longitude= -100)
data_crs = ccrs.PlateCarree()

fig = plt.figure(figsize=(17, 12))
ax = plt.subplot(111, projection = map_crs)
ax.add_feature(cfeature.COASTLINE.with_scale('50m'), linewidth=0.75)
ax.add_feature(cfeature.STATES, linewidth=0.5)

artists = []

for warndt in ['WarnDT'].unique():
    text = ax.text(0.5, 1.02, f'Issued {warndt}', ha= 'center',
                transform = ax.transAxes, fontsize=24 ),
    timestep_artists = [text]

    times_df = df.loc[df['WarnDT'] == warndt]
    
for model in time_df['Model'].unique():
      model_path = time_df.loc[time_df['Model'] == model]
      s = ax.scatter(model_path['Lon'], model_path['Lat'], alpha = 0.5, 
      transform=data_crs, color= model_colors[models])
    
      timestep_artists.append(s)
      artists.append(timestep_artists)
      ax.set_extent([-106, -80, 20, 35], crs=data_crs)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-2-c24564293fcb> in <module>()
#      22 artists = []
#      23
# ---> 24 for warndt in ['WarnDT'].unique():
#      25     text = ax.text(0.5, 1.02, f'Issued {warndt}', ha= 'center',
#      26                 transform = ax.transAxes, fontsize=24 ),
#
# AttributeError: 'list' object has no attribute 'unique'

# %%
# print(type(f))
    # for line in f:        
    #     print('got line', line)
import plotly.express as px

fig = px.scatter_geo(df, lat='Lat',  lon='Lon' )
fig.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-62537454fd5a> in <module>()
#       6 import plotly.express as px
#       7
# ----> 8 fig = px.scatter_geo(df, lat='Lat',  lon='Lon' )
#       9 fig.show()
#
# NameError: name 'df' is not defined

# %%
# print(type(f))
    # for line in f:        
    #     print('got line', line)

import plotly.express as px

fig = px.scatter_geo(df, lat='Lat',  lon='Lon' )
fig.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-8f6132f628a1> in <module>()
#       6 import plotly.express as px
#       7
# ----> 8 fig = px.scatter_geo(df, lat='Lat',  lon='Lon' )
#       9 fig.show()
#
# NameError: name 'df' is not defined

# %%
df['WarnDT'].unique()
# Out:
# array([2021052000, 2021052006, 2021052012, 2021052018, 2021052100,
#        2021052106, 2021052112, 2021052118, 2021052200, 2021052206,
#        2021052212, 2021052218, 2021052300, 2021052306, 2021052312,
#        2021052318, 2021052400])

# %%
import cartopy.crs as ccrs
import cartopy.feature as cfeature
import matplotlib.pyplot as plt
import plotly.express as px
import pandas as pd 

colors =plt.rcParams['axes.prop_cycle'].by_key()['color']
model_colors={}

# for i, model in enumerate(df['Model'].unique()):
#    model_colors[model]= colors[i%10]


map_crs = ccrs.LambertConformal(central_latitude =45, central_longitude= -100)
data_crs = ccrs.PlateCarree()

fig = plt.figure(figsize=(17, 12))
ax = plt.subplot(111, projection = map_crs)
ax.add_feature(cfeature.COASTLINE.with_scale('50m'), linewidth=0.75)
ax.add_feature(cfeature.STATES, linewidth=0.5)

artists = []

for warndt in df['WarnDT'].unique():
    text = ax.text(0.5, 1.02, f'Issued {warndt}', ha= 'center',
                transform = ax.transAxes, fontsize=24 ),
    timestep_artists = [text]

    times_df = df.loc[df['WarnDT'] == warndt]
    
    for model in time_df['Model'].unique():
     model_path = time_df.loc[time_df['Model'] == model]
     s = ax.scatter(model_path['Lon'], model_path['Lat'], alpha = 0.5, 
     transform=data_crs, color= model_colors[models])
    
    timestep_artists.append(s)
    artists.append(timestep_artists)
    ax.set_extent([-106, -80, 20, 35], crs=data_crs)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-e1d9fed05872> in <module>()
#      22 artists = []
#      23
# ---> 24 for warndt in df['WarnDT'].unique():
#      25     text = ax.text(0.5, 1.02, f'Issued {warndt}', ha= 'center',
#      26                 transform = ax.transAxes, fontsize=24 ),
#
# NameError: name 'df' is not defined

# %%
# import cartopy
# Out:
# ...
#      |████████████████████████████████| 12.1MB 222kB/s
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#     Preparing wheel metadata ... done
# ...
#      |████████████████████████████████| 225kB 35.2MB/s
# ...
#   Created wheel for cartopy: filename=Cartopy-0.19.0.post1-cp37-cp37m-linux_x86_64.whl size=12516196 sha256=84846d0fd6bebafdecc2d057f12831756da0f1f3497aea3675c72054f93b7892
#   Stored in directory: /root/.cache/pip/wheels/45/7f/3b/37879587817fd1bbbee7b47312e2401b4f542cccf2fbe9b4ee
# Successfully built cartopy
# ...
#   Created wheel for pyshp: filename=pyshp-2.1.3-cp37-none-any.whl size=37325 sha256=d8590f7199d427f0dc3aa27183236e8f517677577289cbfd8f1aa4ffbc172849
#   Stored in directory: /root/.cache/pip/wheels/76/2b/d4/53e6b9a0fb0a9f9f29664cf82605af8bc81d5ab44d987896dd
# Successfully built pyshp
# ...

# %%
# !pip install cartopy
#!apt-get install cartopy.features

# import cartopy.crs as ccrs
# # import cartopy.features 
# import matplotlib.pyplot as plt 
# %matplotlib inline

# %%
df['WarnDT']
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-b2ff9d3e896d> in <module>()
# ----> 1 df['WarnDT']
#
# NameError: name 'df' is not defined

# %%
# !pip install cartopy
import cartopy.crs as ccrs
import cartopy.feature as cfeature

# %%
import matplotlib.pyplot as plt
import cartopy.crs as ccrs
import cartopy.feature as cfeature
from matplotlib.offsetbox import AnchoredText


colors =plt.rcParams['axes.prop_cycle'].by_key()['color']
model_colors={}

# for i, model in enumerate(df['Model'].unique()):
#    model_colors[model]= colors[i%10]
print(colors)
# Out:
# ['#1f77b4', '#ff7f0e', '#2ca02c', '#d62728', '#9467bd', '#8c564b', '#e377c2', '#7f7f7f', '#bcbd22', '#17becf']

# %%
from matplotlib.animation import ArtistAnimation
from IPython.display import HTML

# %%
anim = ArtistAnimation(fig, artists, interval=1000)
HTML(anim.to_jshtml)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-8-0ee1442ee9f0> in <module>()
# ----> 1 anim = ArtistAnimation(fig, artists, interval=1000)
#       2 HTML(anim.to_jshtml)
#
# NameError: name 'fig' is not defined

# %%
# !pip install cartopy
#!apt-get install cartopy.features

# import cartopy.crs as ccrs
# # import cartopy.features 
# import matplotlib.pyplot as plt 
# %matplotlib inline 

# !pip install cartopy
# import cartopy


# print(type(f))
    # for line in f:        
    #     print('got line', line)

# %%
import matplotlib.pyplot as plt
import cartopy.crs as ccrs
import cartopy.feature as cfeature
from matplotlib.offsetbox import AnchoredText


def main():
    ax = plt.axes(projection=ccrs.PlateCarree())
    ax.set_extent([80, 170, -45, 30])

    # Put a background image on for nice sea rendering.
    ax.stock_img()

    # Create a feature for States/Admin 1 regions at 1:50m from Natural Earth
    states_provinces = cfeature.NaturalEarthFeature(
        category='cultural',
        name='admin_1_states_provinces_lines',
        scale='50m',
        facecolor='none')

    SOURCE = 'Natural Earth'
    LICENSE = 'public domain'

    ax.add_feature(cfeature.LAND)
    ax.add_feature(cfeature.COASTLINE)
    ax.add_feature(states_provinces, edgecolor='gray')

    # Add a text annotation for the license information to the
    # the bottom right corner.
    text = AnchoredText(r'$\mathcircled{{c}}$ {}; license: {}'
                        ''.format(SOURCE, LICENSE),
                        loc=4, prop={'size': 12}, frameon=True)
    ax.add_artist(text)

    plt.show()


if __name__ == '__main__':
    main()
# Out:
# Geometry must be a Point or LineString
