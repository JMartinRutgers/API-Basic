# %% [markdown]
# <a href="https://colab.research.google.com/github/JMartinRutgers/API-Basic/blob/main/Python_regression_excersise.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd 
from scipy import stats 
import statsmodels.formula.api as smf

# %%
myregresionData = pd.read_csv('/content/regression-py.csv')

# %%
myregresionData
# Out:
#         date             geo  billboard  print  broadcast   sales  visits  \
# 0    2/13/17        Kentucky          6      5          1  137452    3974
# 1    2/12/17              NI          8      6          1  147376    3732
# 2     3/7/17        Virginia          1      1          2  148252    3127
# 3    3/14/17             SIC          9      5          3  151842    3091
# 4     2/5/17              DE          6      3          3  155207    4791
# 5     1/3/17              IN          5      4          3  163855    5066
# 6     3/5/17              SJ          3      9          4  175243    3096
# 7     3/1/17              OV          8      1          4  193623    3371
# 8   12/25/16           Texas          1      4          4  198238    4992
# 9   12/23/16              WA          3      6          4  198267    4725
# 10   2/14/17              JK          8      4          5  201070    5026
# 11   1/24/17              PB          5      9          6  202392    2988
# ...

# %%
myregresionData[["date", "sales"]].head(3)
# Out:
#       date   sales
# 0  2/13/17  137452
# 1  2/12/17  147376
# 2   3/7/17  148252

# %%
myregresionData.plot(kind='scatter', x='broadcast', y='sales')

# %%
#Calculate r-squared

slope, intercept, r_value,p_value,std_err= stats.linregress(myregresionData.broadcast,myregresionData.sales)

# %%
#print the r-squared value 
print("r-squared:", r_value)
# Out:
# r-squared: 0.9486630182039945
