# %% [markdown]
# <a href="https://colab.research.google.com/github/JMartinRutgers/API-Basic/blob/main/screp.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Dependencies
from bs4 import BeautifulSoup
import requests

# %%
# URL of page to be scraped
url = 'https://newjersey.craigslist.org/search/sss?sort=rel&query=guitar'

# %%
print(url)
# Out:
# https://newjersey.craigslist.org/search/sss?sort=rel&query=guitar

# %%
# Retrieve page with the requests module
response = requests.get(url)

# %%
# Create BeautifulSoup object; parse with 'html.parser'
soup = BeautifulSoup(response.text, 'html.parser')

# %%
# Examine the results, then determine element that contains sought info
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html>
#  <head>
#   <meta charset="utf-8"/>
#   <meta content="IE=Edge" http-equiv="X-UA-Compatible"/>
#   <meta content="width=device-width,initial-scale=1" name="viewport"/>
#   <meta content="craigslist" property="og:site_name"/>
#   <meta content="preview" name="twitter:card"/>
#   <meta content='north jersey for sale "guitar" - craigslist' property="og:title"/>
#   <meta content='north jersey for sale "guitar" - craigslist' name="description"/>
#   <meta content='north jersey for sale "guitar" - craigslist' property="og:description"/>
#   <meta content="https://newjersey.craigslist.org/search/sss?query=guitar" property="og:url"/>
#   <meta content="true" name="smartbanner:api"/>
#   <meta content="the craigslist app" name="smartbanner:title"/>
#   <meta content="what's old is new" name="smartbanner:author"/>
#   <meta content="/images/app_icon.png" name="smartbanner:icon-apple"/>
#   <meta content="/images/app_icon.png" name="smartbanner:icon-google"/>
#   <meta content="view" name="smartbanner:button"/>
#   <meta content="close" name="smartbanner:close-label"/>
#   <meta content="https://apps.apple.com/us/app/craigslist/id1336642410" name="smartbanner:button-url-apple"/>
#   <meta content="https://play.google.com/store/apps/details?id=org.craigslist.CraigslistMobile" name="smartbanner:button-url-google"/>
#   <meta content="android,ios" name="smartbanner:enabled-platforms"/>
#   <title>
#    north jersey for sale "guitar" - craigslist
#   </title>
#   <link href="https://newjersey.craigslist.org/search/sss?query=guitar" rel="canonical"/>
#   <link href="https://newjersey.craigslist.org/search/sss?s=120&amp;query=guitar&amp;sort=rel" rel="next"/>
#   <script id="ld_breadcrumb_data" type="application/ld+json">
#    {"@context":"https://schema.org","itemListElement":[{"item":{"name":"newjersey.craigslist.org","@id":"https://newjersey.craigslist.org"},"position":1,"@type":"ListItem"},{"item":{"name":"for sale","@id":"https://newjersey.craigslist.org/search/sss"},"position":2,"@type":"ListItem"}],"@type":"BreadcrumbList"}
#   </script>
#   <style type="text/css">
#    body {
#             font-family: sans-serif;
#         }
#
#         #no-js {
#             position: fixed;
#             z-index: 100000;
#             top: 0;
#             bottom: 0;
#             left: 0;
#             right: 0;
#             overflow:auto;
#             margin: 0;
#             background: transparent;
#         }
#
#         #no-js h1 {
#             margin: 0;
#             padding: .5em;
#             color: #00E;
#             background-color: #cccccc;
#         }
#
#         #no-js  p {
#             margin: 1em;
#         }
#
#         .no-js header,
#         .no-js form,
#         .no-js .tsb,
#         .unsupported-browser header,
#         .unsupported-browser form,
#         .unsupported-browser .tsb {
#             display: none;
#         }
#
#         #curtain {
#             display: none;
#             position: fixed;
#             z-index: 9000;
#             top: 0;
#             bottom: 0;
#             left: 0;
#             right: 0;
#             margin: 0;
#             padding: 0;
#             border: 0;
#             background: transparent;
#         }
#
#         .show-curtain #curtain {
#             display: block;
#         }
#
#         #curtain .cover,
#         #curtain .content {
#             position: absolute;
#             display: block;
#             top: 0;
#             bottom: 0;
#             left: 0;
#             right: 0;
#             margin: 0;
#             padding: 0;
#             border: 0;
#         }
#
#         #curtain .cover {
#             z-index: 1;
#             background-color: white;
#         }
#
#         .show-curtain #curtain .cover {
#             opacity: 0.7;
#         }
#
#         .show-curtain.clear #curtain .cover {
#             opacity: 0;
#         }
#
#         .show-curtain.opaque #curtain .cover {
#             opacity: 1;
#         }
#
#         #curtain .content {
#             z-index: 2;
#             background: transparent;
#             color: #00E;
#
#             display: flex;
#             flex-direction: column;
#             justify-content: center;
#             align-items: center;
#         }
#
#         .unrecoverable #curtain .content,
#         .unsupported-browser #curtain .content {
#             display: block;
#             align-items: start;
#         }
#
#         #curtain h1 {
#             margin: 0;
#             padding: .5em;
#             background-color: #cccccc;
#         }
#
#         #curtain  p {
#             margin: 1em;
#             color: black;
#         }
#
#         .pacify #curtain .icom-:after {
#             content: "\eb23";
#         }
#
#         #curtain .text {
#             display: none;
#         }
#
#         .loading #curtain .text.loading,
#         .reading #curtain .text.reading,
#         .writing #curtain .text.writing,
#         .saving #curtain .text.saving,
#         .searching #curtain .text.searching,
#         .unrecoverable #curtain .text.unrecoverable,
#         .message #curtain .text.message {
#             display: block;
#         }
#
#         .unrecoverable #curtain .text.unrecoverable {
#         }
#
#         @keyframes rotate {
#             from {
#                 transform: rotate(0deg);
#             }
#             to {
#                 transform: rotate(359deg);
#             }
#         }
#
#         .pacify #curtain .icom- {
#             font-size: 3em;
#             animation: rotate 2s infinite linear;
#         }
#   </style>
#   <script src="https://www.craigslist.org/static/www/bbe8a523a089547e594fa2f101021699a377645c.js">
#   </script>
#   <script>
#    window.cl.init(
#              'https://www.craigslist.org/static/www/',
#              '',
#              'www',
#              'browsePostings',
#              {
# areaCountry: "US",
# areaID: "170",
# areaRegion: "NJ",
# catAbb: "sss",
# categoryStr: "sss",
# countOfTotalText: "image {count} of {total}",
# currencySymbol: "&#x0024;",
# defaultLocale: "en_US",
# defaultView: "grid",
# expiredFavIDs: null,
# hubLinkText: null,
# hubName: null,
# imageConfig: {"1":{"hostname":"https://images.craigslist.org","sizes":["50x50c","300x300","600x450","1200x900"]},"4":{"hostname":"https://images.craigslist.org","sizes":["50x50c","300x300","600x450","1200x900"]},"0":{"hostname":"https://images.craigslist.org","sizes":["50x50c","300x300","600x450"]},"3":{"hostname":"https://images.craigslist.org","sizes":["50x50c","300x300","600x450","1200x900"]},"2":{"hostname":"https://images.craigslist.org","sizes":["50x50c","300x300","600x450","1200x900"]}},
# lessInfoText: "less info",
# locParams: null,
# locString: "",
# maptileBaseUrl: "//map{s}.craigslist.org/t09/{z}/{x}/{y}.png",
# maxResults: 3000,
# noImageText: "no image",
# pID: null,
# postalLat: null,
# postalLon: null,
# purveyorCategories: {"owner":"sso","dealer":"ssq","all":"sss"},
# purveyorStr: "",
# searchDistance: null,
# sectionAbb: "sss",
# sectionBase: "sss",
# showInfoText: "show info",
# showMapTabs: 1,
# showingBanished: 0,
# showingFavorites: 0,
# starHint: "save this post in your favorites list",
# subarea: null,
# zoomToPosting: null
# },
#              0
#          );
#   </script>
#   <script>
#    window.cl.specialCurtainMessages = {
#             unsupportedBrowser: [
#                 "We've detected you are using a browser that is missing critical features.",
#                 "Please visit craigslist from a modern browser."
#             ],
#             unrecoverableError: [
#                 "There was an error loading the page."
#             ]
#         };
#   </script>
#  </head>
#  <body class="no-js show-curtain opaque search has-map">
#   <iframe id="cl-local-storage" src="https://www.craigslist.org/static/www/localStorage-092e9f9e2f09450529e744902aa7cdb3a5cc868d.html" style="display:none;">
#   </iframe>
#   <section class="page-container" data-areaid="170" id="page-top">
#    <div class="bglogo">
#    </div>
#    <header class="global-header wide">
#     <a class="header-logo" href="https://newjersey.craigslist.org" name="logoLink">
#      CL
#     </a>
#     <nav class="breadcrumbs-container">
#      <form action="/search/sss" class="breadcrumbs-form" id="breadcrumbform" method="get">
#       <input name="sort" type="hidden" value="rel"/>
#       <input name="query" type="hidden" value="guitar"/>
#       <ul class="breadcrumbs ">
#        <li class="crumb area">
#         <span class="no-js">
#          <a href="/">
#           north jersey
#          </a>
#         </span>
#         <select class="js-only" id="areaAbb" name="areaAbb">
#          <option value="newjersey">
#           north jersey
#          </option>
#          <option value="albany">
#           albany, NY
#          </option>
#          <option value="allentown">
#           allentown
#          </option>
#          <option value="altoona">
#           altoona
#          </option>
#          <option value="annapolis">
#           annapolis
#          </option>
#          <option value="baltimore">
#           baltimore
#          </option>
#          <option value="binghamton">
#           binghamton
#          </option>
#          <option value="boston">
#           boston
#          </option>
#          <option value="capecod">
#           cape cod
#          </option>
#          <option value="catskills">
#           catskills
#          </option>
#          <option value="cnj">
#           central NJ
#          </option>
#          <option value="chambersburg">
#           cumberland val
#          </option>
#          <option value="delaware">
#           delaware
#          </option>
#          <option value="newlondon">
#           eastern CT
#          </option>
#          <option value="easternshore">
#           eastern shore
#          </option>
#          <option value="martinsburg">
#           eastern WV
#          </option>
#          <option value="elmira">
#           elmira
#          </option>
#          <option value="fingerlakes">
#           finger lakes
#          </option>
#          <option value="frederick">
#           frederick
#          </option>
#          <option value="glensfalls">
#           glens falls
#          </option>
#          <option value="harrisburg">
#           harrisburg
#          </option>
#          <option value="hartford">
#           hartford
#          </option>
#          <option value="hudsonvalley">
#           hudson valley
#          </option>
#          <option value="ithaca">
#           ithaca
#          </option>
#          <option value="jerseyshore">
#           jersey shore
#          </option>
#          <option value="lancaster">
#           lancaster, PA
#          </option>
#          <option value="longisland">
#           long island
#          </option>
#          <option value="nh">
#           new hampshire
#          </option>
#          <option value="newhaven">
#           new haven
#          </option>
#          <option value="newyork">
#           new york
#          </option>
#          <option value="nwct">
#           northwest CT
#          </option>
#          <option value="oneonta">
#           oneonta
#          </option>
#          <option value="philadelphia">
#           philadelphia
#          </option>
#          <option value="poconos">
#           poconos
#          </option>
#          <option value="reading">
#           reading
#          </option>
#          <option value="providence">
#           rhode island
#          </option>
#          <option value="scranton">
#           scranton
#          </option>
#          <option value="southcoast">
#           south coast
#          </option>
#          <option value="southjersey">
#           south jersey
#          </option>
#          <option value="smd">
#           southern MD
#          </option>
#          <option value="pennstate">
#           state college
#          </option>
#          <option value="syracuse">
#           syracuse
#          </option>
#          <option value="utica">
#           utica
#          </option>
#          <option value="washingtondc">
#           washington, DC
#          </option>
#          <option value="watertown">
#           watertown
#          </option>
#          <option value="westernmass">
#           western mass
#          </option>
#          <option value="williamsport">
#           williamsport
#          </option>
#          <option value="worcester">
#           worcester
#          </option>
#          <option value="york">
#           york, PA
#          </option>
#         </select>
#         <span class="breadcrumb-arrow">
#          &gt;
#         </span>
#        </li>
#        <li class="crumb section">
#         <select id="catAbb" name="catAbb">
#          <option value="ccc">
#           community
#          </option>
#          <option value="eee">
#           events
#          </option>
#          <option selected="" value="sss">
#           for sale
#          </option>
#          <option value="ggg">
#           gigs
#          </option>
#          <option value="hhh">
#           housing
#          </option>
#          <option value="jjj">
#           jobs
#          </option>
#          <option value="rrr">
#           resumes
#          </option>
#          <option value="bbb">
#           services
#          </option>
#         </select>
#         <span class="breadcrumb-arrow">
#          &gt;
#         </span>
#        </li>
#        <li class="crumb category">
#         <select class="js-only" id="subcatAbb">
#          <option value="sss">
#           all
#          </option>
#          <option value="ata">
#           antiques
#          </option>
#          <option value="ppa">
#           appliances
#          </option>
#          <option value="ara">
#           arts+crafts
#          </option>
#          <option value="sna">
#           atvs/utvs/snow
#          </option>
#          <option value="pta">
#           auto parts
#          </option>
#          <option value="wta">
#           auto wheels &amp; tires
#          </option>
#          <option value="ava">
#           aviation
#          </option>
#          <option value="baa">
#           baby+kids
#          </option>
#          <option value="bar">
#           barter
#          </option>
#          <option value="haa">
#           beauty+hlth
#          </option>
#          <option value="bip">
#           bike parts
#          </option>
#          <option value="bia">
#           bikes
#          </option>
#          <option value="bpa">
#           boat parts
#          </option>
#          <option value="boo">
#           boats
#          </option>
#          <option value="bka">
#           books
#          </option>
#          <option value="bfa">
#           business
#          </option>
#          <option value="cta">
#           cars+trucks
#          </option>
#          <option value="ema">
#           cds/dvd/vhs
#          </option>
#          <option value="moa">
#           cell phones
#          </option>
#          <option value="cla">
#           clothes+acc
#          </option>
#          <option value="cba">
#           collectibles
#          </option>
#          <option value="syp">
#           computer parts
#          </option>
#          <option value="sya">
#           computers
#          </option>
#          <option value="ela">
#           electronics
#          </option>
#          <option value="gra">
#           farm+garden
#          </option>
#          <option value="zip">
#           free stuff
#          </option>
#          <option value="fua">
#           furniture
#          </option>
#          <option value="gms">
#           garage sales
#          </option>
#          <option value="foa">
#           general
#          </option>
#          <option value="hva">
#           heavy equipment
#          </option>
#          <option value="hsa">
#           household
#          </option>
#          <option value="jwa">
#           jewelry
#          </option>
#          <option value="maa">
#           materials
#          </option>
#          <option value="mpa">
#           motorcycle parts
#          </option>
#          <option value="mca">
#           motorcycles
#          </option>
#          <option value="msa">
#           music instr
#          </option>
#          <option value="pha">
#           photo+video
#          </option>
#          <option value="rva">
#           RVs
#          </option>
#          <option value="sga">
#           sporting
#          </option>
#          <option value="tia">
#           tickets
#          </option>
#          <option value="tla">
#           tools
#          </option>
#          <option value="taa">
#           toys+games
#          </option>
#          <option value="tra">
#           trailers
#          </option>
#          <option value="vga">
#           video gaming
#          </option>
#          <option value="waa">
#           wanted
#          </option>
#         </select>
#         <span class="no-js">
#          for sale
#         </span>
#         <span class="breadcrumb-arrow">
#          &gt;
#         </span>
#        </li>
#       </ul>
#      </form>
#     </nav>
#     <div class="userlinks">
#      <ul class="user-actions">
#       <li class="user post">
#        <a href="https://post.craigslist.org/c/njy">
#         post
#        </a>
#       </li>
#       <li class="user account">
#        <a href="https://accounts.craigslist.org/login/home">
#         account
#        </a>
#       </li>
#      </ul>
#      <ul class="user-favs-discards">
#       <li class="user">
#        <div class="favorites">
#         <a class="favlink" href="#">
#          <span aria-hidden="true" class="icon icon-star fav">
#          </span>
#          <span class="fav-number">
#           0
#          </span>
#          <span class="fav-label">
#           favorites
#          </span>
#         </a>
#        </div>
#       </li>
#       <li class="user discards">
#        <div class="to-banish-page">
#         <a class="to-banish-page-link" href="#">
#          <span aria-hidden="true" class="icon icon-trash red">
#          </span>
#          <span class="banished_count">
#           0
#          </span>
#          <span class="discards-label">
#           hidden
#          </span>
#         </a>
#        </div>
#       </li>
#      </ul>
#     </div>
#    </header>
#    <header class="global-header narrow">
#     <a class="header-logo" href="https://newjersey.craigslist.org">
#      CL
#     </a>
#     <nav class="breadcrumbs-container">
#      <h1 class="breadcrumbs">
#       north jersey            &gt;
#
# for sale
#      </h1>
#     </nav>
#     <span class="linklike show-wide-header">
#      ...
#     </span>
#    </header>
#    <form action="/search/sss" class="search-form" id="searchform">
#     <div class="querybox">
#      <div class="form-tab js-only">
#       <span class="search-open" title="hide search">
#        «
#       </span>
#       <span class="search-closed" title="show search">
#        »
#       </span>
#      </div>
#      <input autocapitalize="off" autocomplete="off" autocorrect="off" class="flatinput ui-autocomplete-input" data-autocomplete="search" id="query" name="query" placeholder="search for sale" type="text" value="guitar"/>
#      <button class="searchbtn" type="submit">
#       <span aria-hidden="true" class="icon icon-search">
#       </span>
#       <span class="screen-reader-text">
#        press to search craigslist
#       </span>
#      </button>
#      <div class="savealert">
#       <a class="saveme" data-action="save" href="https://accounts.craigslist.org/savesearch/save?URL=https%3A%2F%2Fnewjersey%2Ecraigslist%2Eorg%2Fsearch%2Fsss%3Fquery%3Dguitar%26sort%3Drel" title="save this search">
#        save search
#       </a>
#      </div>
#     </div>
#     <div class="search-options-container">
#      <h1 class="cattitle">
#       <a class="reset" href="https://newjersey.craigslist.org/search/sss" title="clear all search parameters">
#        for sale
#       </a>
#      </h1>
#      <div class="search-options-header linklike">
#       <div aria-hidden="true" class="icon icon-toggle-gear">
#       </div>
#       options
#       <span class="options-close">
#        close
#       </span>
#      </div>
#      <input id="excats" name="excats" type="hidden"/>
#      <input name="sort" type="hidden" value="rel"/>
#      <div class="search-options">
#       <div class="searchgroup categories">
#        <ul class="maincats">
#         <li>
#          <input checked="checked" class="catcheck multi_checkbox" data-abb="msa" id="cat_msa" name="cat_id" type="checkbox" value="98,184"/>
#          <a class="category" href="/search/msa?query=guitar&amp;sort=rel">
#           musical instruments
#          </a>
#          <span class="count">
#           373
#          </span>
#         </li>
#         <li>
#          <input checked="checked" class="catcheck multi_checkbox" data-abb="foa" id="cat_foa" name="cat_id" type="checkbox" value="5,179"/>
#          <a class="category" href="/search/foa?query=guitar&amp;sort=rel">
#           general for sale
#          </a>
#          <span class="count">
#           129
#          </span>
#         </li>
#         <li>
#          <input checked="checked" class="catcheck multi_checkbox" data-abb="cba" id="cat_cba" name="cat_id" type="checkbox" value="95,177"/>
#          <a class="category" href="/search/cba?query=guitar&amp;sort=rel">
#           collectibles
#          </a>
#          <span class="count">
#           127
#          </span>
#         </li>
#         <li>
#          <input checked="checked" class="catcheck multi_checkbox" data-abb="ela" id="cat_ela" name="cat_id" type="checkbox" value="96,167"/>
#          <a class="category" href="/search/ela?query=guitar&amp;sort=rel">
#           electronics
#          </a>
#          <span class="count">
#           13
#          </span>
#         </li>
#         <li>
#          <input checked="checked" class="catcheck multi_checkbox" data-abb="waa" id="cat_waa" name="cat_id" type="checkbox" value="20,190"/>
#          <a class="category" href="/search/waa?query=guitar&amp;sort=rel">
#           wanted
#          </a>
#          <span class="count">
#           10
#          </span>
#         </li>
#         <li class="morecats js-only closed">
#          <span class="linklike closed">
#           <span class="plusminus">
#            +
#           </span>
#           show 40 more
#          </span>
#          <span class="linklike open">
#           <span class="plusminus">
#            –
#           </span>
#           hide 40 more
#          </span>
#          <span class="count">
#           35
#          </span>
#         </li>
#        </ul>
#        <ul class="othercats closed">
#         <li>
#          <input checked="checked" class="catcheck multi_checkbox" data-abb="vga" id="cat_vga" name="cat_id" type="checkbox" value="151,189"/>
#          <a class="category" href="/search/vga?query=guitar&amp;sort=rel">
#           video gaming
#          </a>
#          <span class="count">
#           7
#          </span>
#         </li>
#         <li>
#          <input checked="checked" class="catcheck multi_checkbox" data-abb="bar" id="cat_bar" name="cat_id" type="checkbox" value="42"/>
#          <a class="category" href="/search/bar?query=guitar&amp;sort=rel">
#           barter
#          </a>
#          <span class="count">
#           6
#          </span>
#         </li>
#         <li>
#          <input checked="checked" class="catcheck multi_checkbox" data-abb="taa" id="cat_taa" name="cat_id" type="checkbox" value="132,188"/>
#          <a class="category" href="/search/taa?query=guitar&amp;sort=rel">
#           toys &amp; games
#          </a>
#          <span class="count">
#           5
#          </span>
#         </li>
#         <li>
#          <input checked="checked" class="catcheck multi_checkbox" data-abb="ema" id="cat_ema" name="cat_id" type="checkbox" value="117,175"/>
#          <a class="category" href="/search/ema?query=guitar&amp;sort=rel">
#           cds / dvds / vhs
#          </a>
#          <span class="count">
#           4
#          </span>
#         </li>
#         <li>
#          <input checked="checked" class="catcheck multi_checkbox" data-abb="ata" id="cat_ata" name="cat_id" type="checkbox" value="150,169"/>
#          <a class="category" href="/search/ata?query=guitar&amp;sort=rel">
#           antiques
#          </a>
#          <span class="count">
#           2
#          </span>
#         </li>
#         <li>
#          <input checked="checked" class="catcheck multi_checkbox" data-abb="baa" id="cat_baa" name="cat_id" type="checkbox" value="107,171"/>
#          <a class="category" href="/search/baa?query=guitar&amp;sort=rel">
#           baby &amp; kid stuff
#          </a>
#          <span class="count">
#           2
#          </span>
#         </li>
#         <li>
#          <input checked="checked" class="catcheck multi_checkbox" data-abb="bka" id="cat_bka" name="cat_id" type="checkbox" value="92,173"/>
#          <a class="category" href="/search/bka?query=guitar&amp;sort=rel">
#           books &amp; magazines
#          </a>
#          <span class="count">
#           2
#          </span>
#         </li>
#         <li>
#          <input checked="checked" class="catcheck multi_checkbox" data-abb="pha" id="cat_pha" name="cat_id" type="checkbox" value="137,185"/>
#          <a class="category" href="/search/pha?query=guitar&amp;sort=rel">
#           photo/video
#          </a>
#          <span class="count">
#           2
#          </span>
#         </li>
#         <li>
#          <input checked="checked" class="catcheck multi_checkbox" data-abb="bfa" id="cat_bfa" name="cat_id" type="checkbox" value="134,174"/>
#          <a class="category" href="/search/bfa?query=guitar&amp;sort=rel">
#           business
#          </a>
#          <span class="count">
#           1
#          </span>
#         </li>
#         <li>
#          <input checked="checked" class="catcheck multi_checkbox" data-abb="gms" id="cat_gms" name="cat_id" type="checkbox" value="73"/>
#          <a class="category" href="/search/gms?query=guitar&amp;sort=rel">
#           garage &amp; moving sales
#          </a>
#          <span class="count">
#           1
#          </span>
#         </li>
#         <li>
#          <input checked="checked" class="catcheck multi_checkbox" data-abb="hsa" id="cat_hsa" name="cat_id" type="checkbox" value="97,181"/>
#          <a class="category" href="/search/hsa?query=guitar&amp;sort=rel">
#           household items
#          </a>
#          <span class="count">
#           1
#          </span>
#         </li>
#         <li>
#          <input checked="checked" class="catcheck multi_checkbox" data-abb="maa" id="cat_maa" name="cat_id" type="checkbox" value="136,183"/>
#          <a class="category" href="/search/maa?query=guitar&amp;sort=rel">
#           materials
#          </a>
#          <span class="count">
#           1
#          </span>
#         </li>
#         <li>
#          <input checked="checked" class="catcheck multi_checkbox" data-abb="sga" id="cat_sga" name="cat_id" type="checkbox" value="93,186"/>
#          <a class="category" href="/search/sga?query=guitar&amp;sort=rel">
#           sporting goods
#          </a>
#          <span class="count">
#           1
#          </span>
#         </li>
#         <li>
#          <input checked="checked" class="catcheck multi_checkbox" data-abb="ppa" id="cat_ppa" name="cat_id" type="checkbox" value="149,162"/>
#          <a class="category" href="/search/ppa?query=guitar&amp;sort=rel">
#           appliances
#          </a>
#          <span class="count">
#           0
#          </span>
#         </li>
#         <li>
#          <input checked="checked" class="catcheck multi_checkbox" data-abb="ara" id="cat_ara" name="cat_id" type="checkbox" value="135,170"/>
#          <a class="category" href="/search/ara?query=guitar&amp;sort=rel">
#           arts &amp; crafts
#          </a>
#          <span class="count">
#           0
#          </span>
#         </li>
#         <li>
#          <input checked="checked" class="catcheck multi_checkbox" data-abb="sna" id="cat_sna" name="cat_id" type="checkbox" value="191,192"/>
#          <a class="category" href="/search/sna?query=guitar&amp;sort=rel">
#           atvs, utvs, snowmobiles
#          </a>
#          <span class="count">
#           0
#          </span>
#         </li>
#         <li>
#          <input checked="checked" class="catcheck multi_checkbox" data-abb="pta" id="cat_pta" name="cat_id" type="checkbox" value="122,163"/>
#          <a class="category" href="/search/pta?query=guitar&amp;sort=rel">
#           auto parts
#          </a>
#          <span class="count">
#           0
#          </span>
#         </li>
#         <li>
#          <input checked="checked" class="catcheck multi_checkbox" data-abb="wta" id="cat_wta" name="cat_id" type="checkbox" value="203,204"/>
#          <a class="category" href="/search/wta?query=guitar&amp;sort=rel">
#           auto wheels &amp; tires
#          </a>
#          <span class="count">
#           0
#          </span>
#         </li>
#         <li>
#          <input checked="checked" class="catcheck multi_checkbox" data-abb="ava" id="cat_ava" name="cat_id" type="checkbox" value="208,209"/>
#          <a class="category" href="/search/ava?query=guitar&amp;sort=rel">
#           aviation
#          </a>
#          <span class="count">
#           0
#          </span>
#         </li>
#         <li>
#          <input checked="checked" class="catcheck multi_checkbox" data-abb="bip" id="cat_bip" name="cat_id" type="checkbox" value="197,198"/>
#          <a class="category" href="/search/bip?query=guitar&amp;sort=rel">
#           bicycle parts
#          </a>
#          <span class="count">
#           0
#          </span>
#         </li>
#         <li>
#          <input checked="checked" class="catcheck multi_checkbox" data-abb="bia" id="cat_bia" name="cat_id" type="checkbox" value="68,172"/>
#          <a class="category" href="/search/bia?query=guitar&amp;sort=rel">
#           bicycles
#          </a>
#          <span class="count">
#           0
#          </span>
#         </li>
#         <li>
#          <input checked="checked" class="catcheck multi_checkbox" data-abb="bpa" id="cat_bpa" name="cat_id" type="checkbox" value="201,202"/>
#          <a class="category" href="/search/bpa?query=guitar&amp;sort=rel">
#           boat parts &amp; accessories
#          </a>
#          <span class="count">
#           0
#          </span>
#         </li>
#         <li>
#          <input checked="checked" class="catcheck multi_checkbox" data-abb="boo" id="cat_boo" name="cat_id" type="checkbox" value="119,164"/>
#          <a class="category" href="/search/boo?query=guitar&amp;sort=rel">
#           boats
#          </a>
#          <span class="count">
#           0
#          </span>
#         </li>
#         <li>
#          <input checked="checked" class="catcheck multi_checkbox" data-abb="cta" id="cat_cta" name="cat_id" type="checkbox" value="145,146"/>
#          <a class="category" href="/search/cta?query=guitar&amp;sort=rel">
#           cars &amp; trucks
#          </a>
#          <span class="count">
#           0
#          </span>
#         </li>
#         <li>
#          <input checked="checked" class="catcheck multi_checkbox" data-abb="moa" id="cat_moa" name="cat_id" type="checkbox" value="153,165"/>
#          <a class="category" href="/search/moa?query=guitar&amp;sort=rel">
#           cell phones
#          </a>
#          <span class="count">
#           0
#          </span>
#         </li>
#         <li>
#          <input checked="checked" class="catcheck multi_checkbox" data-abb="cla" id="cat_cla" name="cat_id" type="checkbox" value="94,176"/>
#          <a class="category" href="/search/cla?query=guitar&amp;sort=rel">
#           clothing &amp; accessories
#          </a>
#          <span class="count">
#           0
#          </span>
#         </li>
#         <li>
#          <input checked="checked" class="catcheck multi_checkbox" data-abb="syp" id="cat_syp" name="cat_id" type="checkbox" value="199,200"/>
#          <a class="category" href="/search/syp?query=guitar&amp;sort=rel">
#           computer parts
#          </a>
#          <span class="count">
#           0
#          </span>
#         </li>
#         <li>
#          <input checked="checked" class="catcheck multi_checkbox" data-abb="sya" id="cat_sya" name="cat_id" type="checkbox" value="7,166"/>
#          <a class="category" href="/search/sya?query=guitar&amp;sort=rel">
#           computers
#          </a>
#          <span class="count">
#           0
#          </span>
#         </li>
#         <li>
#          <input checked="checked" class="catcheck multi_checkbox" data-abb="gra" id="cat_gra" name="cat_id" type="checkbox" value="133,178"/>
#          <a class="category" href="/search/gra?query=guitar&amp;sort=rel">
#           farm &amp; garden
#          </a>
#          <span class="count">
#           0
#          </span>
#         </li>
#         <li>
#          <input checked="checked" class="catcheck multi_checkbox" data-abb="zip" id="cat_zip" name="cat_id" type="checkbox" value="101"/>
#          <a class="category" href="/search/zip?query=guitar&amp;sort=rel">
#           free stuff
#          </a>
#          <span class="count">
#           0
#          </span>
#         </li>
#         <li>
#          <input checked="checked" class="catcheck multi_checkbox" data-abb="fua" id="cat_fua" name="cat_id" type="checkbox" value="141,142"/>
#          <a class="category" href="/search/fua?query=guitar&amp;sort=rel">
#           furniture
#          </a>
#          <span class="count">
#           0
#          </span>
#         </li>
#         <li>
#          <input checked="checked" class="catcheck multi_checkbox" data-abb="haa" id="cat_haa" name="cat_id" type="checkbox" value="152,180"/>
#          <a class="category" href="/search/haa?query=guitar&amp;sort=rel">
#           health and beauty
#          </a>
#          <span class="count">
#           0
#          </span>
#         </li>
#         <li>
#          <input checked="checked" class="catcheck multi_checkbox" data-abb="hva" id="cat_hva" name="cat_id" type="checkbox" value="193,194"/>
#          <a class="category" href="/search/hva?query=guitar&amp;sort=rel">
#           heavy equipment
#          </a>
#          <span class="count">
#           0
#          </span>
#         </li>
#         <li>
#          <input checked="checked" class="catcheck multi_checkbox" data-abb="jwa" id="cat_jwa" name="cat_id" type="checkbox" value="120,182"/>
#          <a class="category" href="/search/jwa?query=guitar&amp;sort=rel">
#           jewelry
#          </a>
#          <span class="count">
#           0
#          </span>
#         </li>
#         <li>
#          <input checked="checked" class="catcheck multi_checkbox" data-abb="mpa" id="cat_mpa" name="cat_id" type="checkbox" value="195,196"/>
#          <a class="category" href="/search/mpa?query=guitar&amp;sort=rel">
#           motorcycle parts &amp; accessories
#          </a>
#          <span class="count">
#           0
#          </span>
#         </li>
#         <li>
#          <input checked="checked" class="catcheck multi_checkbox" data-abb="mca" id="cat_mca" name="cat_id" type="checkbox" value="69,160"/>
#          <a class="category" href="/search/mca?query=guitar&amp;sort=rel">
#           motorcycles/scooters
#          </a>
#          <span class="count">
#           0
#          </span>
#         </li>
#         <li>
#          <input checked="checked" class="catcheck multi_checkbox" data-abb="rva" id="cat_rva" name="cat_id" type="checkbox" value="124,168"/>
#          <a class="category" href="/search/rva?query=guitar&amp;sort=rel">
#           recreational vehicles
#          </a>
#          <span class="count">
#           0
#          </span>
#         </li>
#         <li>
#          <input checked="checked" class="catcheck multi_checkbox" data-abb="tia" id="cat_tia" name="cat_id" type="checkbox" value="44,161"/>
#          <a class="category" href="/search/tia?query=guitar&amp;sort=rel">
#           tickets
#          </a>
#          <span class="count">
#           0
#          </span>
#         </li>
#         <li>
#          <input checked="checked" class="catcheck multi_checkbox" data-abb="tla" id="cat_tla" name="cat_id" type="checkbox" value="118,187"/>
#          <a class="category" href="/search/tla?query=guitar&amp;sort=rel">
#           tools
#          </a>
#          <span class="count">
#           0
#          </span>
#         </li>
#         <li>
#          <input checked="checked" class="catcheck multi_checkbox" data-abb="tra" id="cat_tra" name="cat_id" type="checkbox" value="205,206"/>
#          <a class="category" href="/search/tra?query=guitar&amp;sort=rel">
#           trailers
#          </a>
#          <span class="count">
#           0
#          </span>
#         </li>
#        </ul>
#        <div class="selectall js-only checked">
#         <label>
#          <input checked="checked" class="catcheck selectallcb" type="checkbox"/>
#          <span class="all linklike">
#           select all
#          </span>
#         </label>
#        </div>
#       </div>
#       <input name="userid" type="hidden" value="">
#        <div id="purveyor">
#         <ul class="searchgroup buttongroup purveyor">
#          <li class="button sel">
#           <a data-val="all" href="/search/sss?query=guitar&amp;sort=rel" id="all-purveyor">
#            all
#           </a>
#          </li>
#          <li class="button ">
#           <a data-val="owner" href="/search/sss?purveyor=owner&amp;query=guitar&amp;sort=rel" id="owner-purveyor">
#            owner
#           </a>
#          </li>
#          <li class="button ">
#           <a data-val="dealer" href="/search/sss?purveyor=dealer&amp;query=guitar&amp;sort=rel" id="dealer-purveyor">
#            dealer
#           </a>
#          </li>
#         </ul>
#        </div>
#        <div class="searchgroup" id="basic-bools">
#         <ul>
#          <li>
#           <label class="srchType">
#            <input class="" name="srchType" type="checkbox" value="T"/>
#            search titles only
#           </label>
#          </li>
#          <li>
#           <label class="hasPic">
#            <input class="autosubmit" name="hasPic" type="checkbox" value="1"/>
#            has image
#           </label>
#          </li>
#          <li>
#           <label class="postedToday">
#            <input class="autosubmit" name="postedToday" type="checkbox" value="1"/>
#            posted today
#           </label>
#          </li>
#          <li>
#           <label class="bundleDuplicates">
#            <input class="autosubmit" name="bundleDuplicates" type="checkbox" value="1"/>
#            bundle duplicates
#           </label>
#          </li>
#          <li>
#           <label class="searchNearby">
#            <input class="autosubmit" name="searchNearby" type="checkbox" value="1"/>
#            include nearby areas
#           </label>
#          </li>
#         </ul>
#         <ul class="js-only nearbyAreas ">
#          <li class="nearbyZone nearbyZone_3">
#           <label class="nearby">
#            <input class="use-id nearbyArea" disabled="disabled" id="nearbyArea_19" name="nearbyArea" type="checkbox" value="59">
#             albany, NY
#             <small>
#              (alb)
#             </small>
#            </input>
#           </label>
#          </li>
#          <li class="nearbyZone nearbyZone_7">
#           <label class="nearby">
#            <input class="use-id nearbyArea" disabled="disabled" id="nearbyArea_44" name="nearbyArea" type="checkbox" value="355">
#             altoona-johnstown
#             <small>
#              (aoo)
#             </small>
#            </input>
#           </label>
#          </li>
#          <li class="nearbyZone nearbyZone_6">
#           <label class="nearby">
#            <input class="use-id nearbyArea" disabled="disabled" id="nearbyArea_36" name="nearbyArea" type="checkbox" value="460">
#             annapolis, MD
#             <small>
#              (anp)
#             </small>
#            </input>
#           </label>
#          </li>
#          <li class="nearbyZone nearbyZone_5">
#           <label class="nearby">
#            <input class="use-id nearbyArea" disabled="disabled" id="nearbyArea_32" name="nearbyArea" type="checkbox" value="34">
#             baltimore, MD
#             <small>
#              (bal)
#             </small>
#            </input>
#           </label>
#          </li>
#          <li class="nearbyZone nearbyZone_3">
#           <label class="nearby">
#            <input class="use-id nearbyArea" disabled="disabled" id="nearbyArea_18" name="nearbyArea" type="checkbox" value="248">
#             binghamton, NY
#             <small>
#              (bgm)
#             </small>
#            </input>
#           </label>
#          </li>
#          <li class="nearbyZone nearbyZone_6">
#           <label class="nearby">
#            <input class="use-id nearbyArea" disabled="disabled" id="nearbyArea_37" name="nearbyArea" type="checkbox" value="4">
#             boston
#             <small>
#              (bos)
#             </small>
#            </input>
#           </label>
#          </li>
#          <li class="nearbyZone nearbyZone_9">
#           <label class="nearby">
#            <input class="use-id nearbyArea" disabled="disabled" id="nearbyArea_56" name="nearbyArea" type="checkbox" value="40">
#             buffalo, NY
#             <small>
#              (buf)
#             </small>
#            </input>
#           </label>
#          </li>
#          <li class="nearbyZone nearbyZone_7">
#           <label class="nearby">
#            <input class="use-id nearbyArea" disabled="disabled" id="nearbyArea_42" name="nearbyArea" type="checkbox" value="239">
#             cape cod / islands
#             <small>
#              (cap)
#             </small>
#            </input>
#           </label>
#          </li>
#          <li class="nearbyZone nearbyZone_1">
#           <label class="nearby">
#            <input class="use-id nearbyArea" disabled="disabled" id="nearbyArea_8" name="nearbyArea" type="checkbox" value="451">
#             catskills
#             <small>
#              (cat)
#             </small>
#            </input>
#           </label>
#          </li>
#          <li class="">
#           <label class="nearby">
#            <input class="use-id nearbyArea" disabled="disabled" id="nearbyArea_1" name="nearbyArea" type="checkbox" value="349">
#             central NJ
#             <small>
#              (cnj)
#             </small>
#            </input>
#           </label>
#          </li>
#          <li class="nearbyZone nearbyZone_10">
#           <label class="nearby">
#            <input class="use-id nearbyArea" disabled="disabled" id="nearbyArea_61" name="nearbyArea" type="checkbox" value="290">
#             charlottesville, VA
#             <small>
#              (uva)
#             </small>
#            </input>
#           </label>
#          </li>
#          <li class="nearbyZone nearbyZone_9">
#           <label class="nearby">
#            <input class="use-id nearbyArea" disabled="disabled" id="nearbyArea_57" name="nearbyArea" type="checkbox" value="452">
#             chautauqua, NY
#             <small>
#              (chq)
#             </small>
#            </input>
#           </label>
#          </li>
#          <li class="nearbyZone nearbyZone_6">
#           <label class="nearby">
#            <input class="use-id nearbyArea" disabled="disabled" id="nearbyArea_39" name="nearbyArea" type="checkbox" value="705">
#             cumberland valley
#             <small>
#              (cbg)
#             </small>
#            </input>
#           </label>
#          </li>
#          <li class="nearbyZone nearbyZone_3">
#           <label class="nearby">
#            <input class="use-id nearbyArea" disabled="disabled" id="nearbyArea_21" name="nearbyArea" type="checkbox" value="193">
#             delaware
#             <small>
#              (dlw)
#             </small>
#            </input>
#           </label>
#          </li>
#          <li class="nearbyZone nearbyZone_2">
#           <label class="nearby">
#            <input class="use-id nearbyArea" disabled="disabled" id="nearbyArea_15" name="nearbyArea" type="checkbox" value="281">
#             eastern CT
#             <small>
#              (nlo)
#             </small>
#            </input>
#           </label>
#          </li>
#          <li class="nearbyZone nearbyZone_7">
#           <label class="nearby">
#            <input class="use-id nearbyArea" disabled="disabled" id="nearbyArea_45" name="nearbyArea" type="checkbox" value="444">
#             eastern panhandle
#             <small>
#              (ewv)
#             </small>
#            </input>
#           </label>
#          </li>
#          <li class="nearbyZone nearbyZone_5">
#           <label class="nearby">
#            <input class="use-id nearbyArea" disabled="disabled" id="nearbyArea_34" name="nearbyArea" type="checkbox" value="328">
#             eastern shore
#             <small>
#              (esh)
#             </small>
#            </input>
#           </label>
#          </li>
#          <li class="nearbyZone nearbyZone_4">
#           <label class="nearby">
#            <input class="use-id nearbyArea" disabled="disabled" id="nearbyArea_27" name="nearbyArea" type="checkbox" value="453">
#             elmira-corning
#             <small>
#              (elm)
#             </small>
#            </input>
#           </label>
#          </li>
#          <li class="nearbyZone nearbyZone_5">
#           <label class="nearby">
#            <input class="use-id nearbyArea" disabled="disabled" id="nearbyArea_33" name="nearbyArea" type="checkbox" value="685">
#             finger lakes, NY
#             <small>
#              (fgl)
#             </small>
#            </input>
#           </label>
#          </li>
#          <li class="nearbyZone nearbyZone_6">
#           <label class="nearby">
#            <input class="use-id nearbyArea" disabled="disabled" id="nearbyArea_40" name="nearbyArea" type="checkbox" value="633">
#             frederick, MD
#             <small>
#              (fdk)
#             </small>
#            </input>
#           </label>
#          </li>
#          <li class="nearbyZone nearbyZone_8">
#           <label class="nearby">
#            <input class="use-id nearbyArea" disabled="disabled" id="nearbyArea_51" name="nearbyArea" type="checkbox" value="457">
#             fredericksburg, VA
#             <small>
#              (ezf)
#             </small>
#            </input>
#           </label>
#          </li>
#          <li class="nearbyZone nearbyZone_5">
#           <label class="nearby">
#            <input class="use-id nearbyArea" disabled="disabled" id="nearbyArea_30" name="nearbyArea" type="checkbox" value="686">
#             glens falls, NY
#             <small>
#              (gfl)
#             </small>
#            </input>
#           </label>
#          </li>
#          <li class="nearbyZone nearbyZone_3">
#           <label class="nearby">
#            <input class="use-id nearbyArea" disabled="disabled" id="nearbyArea_22" name="nearbyArea" type="checkbox" value="166">
#             harrisburg, PA
#             <small>
#              (hrs)
#             </small>
#            </input>
#           </label>
#          </li>
#          <li class="nearbyZone nearbyZone_9">
#           <label class="nearby">
#            <input class="use-id nearbyArea" disabled="disabled" id="nearbyArea_59" name="nearbyArea" type="checkbox" value="447">
#             harrisonburg, VA
#             <small>
#              (shd)
#             </small>
#            </input>
#           </label>
#          </li>
#          <li class="nearbyZone nearbyZone_2">
#           <label class="nearby">
#            <input class="use-id nearbyArea" disabled="disabled" id="nearbyArea_12" name="nearbyArea" type="checkbox" value="44">
#             hartford, CT
#             <small>
#              (htf)
#             </small>
#            </input>
#           </label>
#          </li>
#          <li class="">
#           <label class="nearby">
#            <input class="use-id nearbyArea" disabled="disabled" id="nearbyArea_3" name="nearbyArea" type="checkbox" value="249">
#             hudson valley, NY
#             <small>
#              (hud)
#             </small>
#            </input>
#           </label>
#          </li>
#          <li class="nearbyZone nearbyZone_4">
#           <label class="nearby">
#            <input class="use-id nearbyArea" disabled="disabled" id="nearbyArea_28" name="nearbyArea" type="checkbox" value="201">
#             ithaca, NY
#             <small>
#              (ith)
#             </small>
#            </input>
#           </label>
#          </li>
#          <li class="">
#           <label class="nearby">
#            <input class="use-id nearbyArea" disabled="disabled" id="nearbyArea_2" name="nearbyArea" type="checkbox" value="561">
#             jersey shore
#             <small>
#              (jys)
#             </small>
#            </input>
#           </label>
#          </li>
#          <li class="nearbyZone nearbyZone_3">
#           <label class="nearby">
#            <input class="use-id nearbyArea" disabled="disabled" id="nearbyArea_20" name="nearbyArea" type="checkbox" value="279">
#             lancaster, PA
#             <small>
#              (lns)
#             </small>
#            </input>
#           </label>
#          </li>
#          <li class="nearbyZone nearbyZone_1">
#           <label class="nearby">
#            <input class="use-id nearbyArea" disabled="disabled" id="nearbyArea_7" name="nearbyArea" type="checkbox" value="167">
#             lehigh valley
#             <small>
#              (alt)
#             </small>
#            </input>
#           </label>
#          </li>
#          <li class="">
#           <label class="nearby">
#            <input class="use-id nearbyArea" disabled="disabled" id="nearbyArea_4" name="nearbyArea" type="checkbox" value="250">
#             long island, NY
#             <small>
#              (isp)
#             </small>
#            </input>
#           </label>
# ...
#           Ibanez AEL10LE-BK-14-02 Acoustic Guitar and Case
#          </a>
#         </h3>
#         <span class="result-meta">
#          <span class="result-price">
#           $275
#          </span>
#          <span class="result-tags">
#           <span class="pictag">
#            pic
#           </span>
#          </span>
#          <span class="banish icon icon-trash" role="button">
#           <span class="screen-reader-text">
#            hide this posting
#           </span>
#          </span>
#          <span aria-hidden="true" class="unbanish icon icon-trash red" role="button">
#          </span>
#          <a class="restore-link" href="#">
#           <span class="restore-narrow-text">
#            restore
#           </span>
#           <span class="restore-wide-text">
#            restore this posting
#           </span>
#          </a>
#         </span>
#        </div>
#       </li>
#       <li class="result-row" data-pid="7564283875" data-repost-of="7495211267">
#        <a class="result-image gallery" data-ids="3:00n0n_9lmJ4hWkBsaz_0CI0t2,3:00505_jPv2r0Pn7Ryz_0CI0t2,3:00g0g_8pTX7k2wop4z_0CI0t2,3:00n0n_7IBFfdhOOACz_0CI0t2" href="https://newjersey.craigslist.org/msg/d/stanhope-zoom-g1xon-guitar-effects-pedal/7564283875.html">
#         <span class="result-price">
#          $75
#         </span>
#        </a>
#        <div class="result-info">
#         <span class="icon icon-star" role="button">
#          <span class="screen-reader-text">
#           favorite this post
#          </span>
#         </span>
#         <time class="result-date" datetime="2022-12-30 22:03" title="Fri 30 Dec 10:03:12 PM">
#          Dec 30
#         </time>
#         <h3 class="result-heading">
#          <a class="result-title hdrlnk" data-id="7564283875" href="https://newjersey.craigslist.org/msg/d/stanhope-zoom-g1xon-guitar-effects-pedal/7564283875.html" id="postid_7564283875">
#           Zoom G1Xon guitar effects pedal
#          </a>
#         </h3>
#         <span class="result-meta">
#          <span class="result-price">
#           $75
#          </span>
#          <span class="result-hood">
#           (stanhope)
#          </span>
#          <span class="result-tags">
#           <span class="pictag">
#            pic
#           </span>
#          </span>
#          <span class="banish icon icon-trash" role="button">
#           <span class="screen-reader-text">
#            hide this posting
#           </span>
#          </span>
#          <span aria-hidden="true" class="unbanish icon icon-trash red" role="button">
#          </span>
#          <a class="restore-link" href="#">
#           <span class="restore-narrow-text">
#            restore
#           </span>
#           <span class="restore-wide-text">
#            restore this posting
#           </span>
#          </a>
#         </span>
#        </div>
#       </li>
#       <li class="result-row" data-pid="7564190576" data-repost-of="7488284779">
#        <a class="result-image gallery" data-ids="3:01616_kX6JaJwcXrlz_0CI0t2,3:01515_7zRtJDaXDZvz_0t20CI,3:00d0d_kfvPlKO34sAz_0CI0t2,3:01313_gXQUWroHxxcz_0t20CI,3:00h0h_7X12FdNzEwz_0CI0t2,3:00909_54XiGlwXo50z_0CI0t2,3:00W0W_dxfmJo0SRkxz_0CI0t2,3:00404_eP41ZjaQ03rz_0CI0t2,3:00u0u_kOdgnr3DNnHz_0CI0t2,3:00I0I_9GtQ0lSndhhz_0CI0t2,3:00d0d_8rbIRoTImnSz_0CI0t2,3:00h0h_hjcn0Re2w1kz_0CI0t2,3:00l0l_6h2eJlxfcEVz_0CI0t2,3:00a0a_7l5T09cCjqpz_0CI0t2,3:00O0O_jxFMoBsHj1Gz_0CI0t2,3:00u0u_7mIH6WdOCGkz_0CI0t2,3:00O0O_g6PmRUrFHsiz_0t20CI,3:00x0x_a59JL2ZqSFRz_0t20CI,3:00101_32MtH3UzJKOz_0CI0t2,3:00W0W_1TuRvqcGDDez_0CI0t2,3:00909_71dOncdrtObz_0CI0t2,3:01515_fsM2OMmJUTpz_0CI0t2,3:00505_j1rPduUA4jaz_0t20CI,3:00q0q_64hfcfuGwsvz_0t20CI" href="https://newjersey.craigslist.org/msg/d/paramus-2022-taylor-american-dream-ad17/7564190576.html">
#         <span class="result-price">
#          $0
#         </span>
#        </a>
#        <div class="result-info">
#         <span class="icon icon-star" role="button">
#          <span class="screen-reader-text">
#           favorite this post
#          </span>
#         </span>
#         <time class="result-date" datetime="2022-12-30 20:23" title="Fri 30 Dec 08:23:48 PM">
#          Dec 30
#         </time>
#         <h3 class="result-heading">
#          <a class="result-title hdrlnk" data-id="7564190576" href="https://newjersey.craigslist.org/msg/d/paramus-2022-taylor-american-dream-ad17/7564190576.html" id="postid_7564190576">
#           2022 Taylor American Dream AD17 Acoustic Guitar - Natural
#          </a>
#         </h3>
#         <span class="result-meta">
#          <span class="result-price">
#           $0
#          </span>
#          <span class="result-hood">
#           (Paramus)
#          </span>
#          <span class="result-tags">
#           <span class="pictag">
#            pic
#           </span>
#          </span>
#          <span class="banish icon icon-trash" role="button">
#           <span class="screen-reader-text">
#            hide this posting
#           </span>
#          </span>
#          <span aria-hidden="true" class="unbanish icon icon-trash red" role="button">
#          </span>
#          <a class="restore-link" href="#">
#           <span class="restore-narrow-text">
#            restore
#           </span>
#           <span class="restore-wide-text">
#            restore this posting
#           </span>
#          </a>
#         </span>
#        </div>
#       </li>
#       <li class="result-row" data-pid="7563346890">
#        <a class="result-image gallery" data-ids="3:00202_5KieFEqy5w0z_0lT0t2,3:00303_6yBXN3L1I7sz_0jt0t2,3:00B0B_eIoY7kQs4OJz_0aP0g8,3:00o0o_9srcKITsKkMz_0wg0lv,3:00j0j_3Y1dsxPZgTTz_0jm0t2,3:00N0N_kIX2xroKnlOz_0wg0lv,3:01717_1AXr59T1BXhz_0wg0lv" href="https://newjersey.craigslist.org/msg/d/hope-customized-squier-bass-guitar/7563346890.html">
#         <span class="result-price">
#          $570
#         </span>
#        </a>
#        <div class="result-info">
#         <span class="icon icon-star" role="button">
#          <span class="screen-reader-text">
#           favorite this post
#          </span>
#         </span>
#         <time class="result-date" datetime="2022-12-30 17:43" title="Fri 30 Dec 05:43:37 PM">
#          Dec 30
#         </time>
#         <h3 class="result-heading">
#          <a class="result-title hdrlnk" data-id="7563346890" href="https://newjersey.craigslist.org/msg/d/hope-customized-squier-bass-guitar/7563346890.html" id="postid_7563346890">
#           CUSTOMIZED Squier Bass Guitar, Hartke Amp &amp; 4x10 Cab
#          </a>
#         </h3>
#         <span class="result-meta">
#          <span class="result-price">
#           $570
#          </span>
#          <span class="result-tags">
#           <span class="pictag">
#            pic
#           </span>
#          </span>
#          <span class="banish icon icon-trash" role="button">
#           <span class="screen-reader-text">
#            hide this posting
#           </span>
#          </span>
#          <span aria-hidden="true" class="unbanish icon icon-trash red" role="button">
#          </span>
#          <a class="restore-link" href="#">
#           <span class="restore-narrow-text">
#            restore
#           </span>
#           <span class="restore-wide-text">
#            restore this posting
#           </span>
#          </a>
#         </span>
#        </div>
#       </li>
#      </ul>
#     </div>
#     <div class="search-legend bottom">
#      <div class="search-view">
#       <span class="buttongroup">
#        <a class="backtotop button" href="#page-top">
#         ^ back to top
#        </a>
#       </span>
#      </div>
#      <div class="search-sort">
#       <span class="buttongroup">
#        <a class="backtotop button" href="#page-top">
#         ^ back to top
#        </a>
#       </span>
#      </div>
#      <div class="paginator buttongroup firstpage">
#       <span class="resulttotal">
#        <span class="for-map">
#         showing
#         <span class="displaycountShow">
#          ...
#         </span>
#         postings
#         <span class="zoom-out-for-more" style="display: none">
#          -
#          <a href="">
#           zoom out for all
#           <span class="total">
#            687
#           </span>
#          </a>
#         </span>
#        </span>
#       </span>
#       <span class="buttons">
#        <a class="button first" href="/search/sss?query=guitar&amp;sort=rel" title="first page">
#         &lt;&lt;
#        </a>
#        <span class="button first" title="first page">
#         &lt;&lt;
#        </span>
#        <a class="button prev" href="/search/sss?query=guitar&amp;sort=rel" title="previous page">
#         &lt; prev
#        </a>
#        <span class="button prev" title="previous page">
#         &lt; prev
#        </span>
#        <span class="button pagenum">
#         <span class="range">
#          <span class="rangeFrom">
#           1
#          </span>
#          -
#          <span class="rangeTo">
#           120
#          </span>
#         </span>
#         /
#         <span class="totalcount">
#          687
#         </span>
#        </span>
#        <a class="button next" href="/search/sss?s=120&amp;query=guitar&amp;sort=rel" title="next page">
#         next &gt;
#        </a>
#        <span class="button next" title="next page">
#         next &gt;
#        </span>
#       </span>
#      </div>
#     </div>
#     <section class="blurbs">
#     </section>
#     <div id="floater">
#      <img alt="" class="loading" src="//www.craigslist.org/images/animated-spinny.gif"/>
#      <img alt="" class="payload" src="//www.craigslist.org/images/animated-spinny.gif"/>
#     </div>
#    </form>
#    <aside class="tsb">
#     <ul>
#      <li>
#       <a href="https://www.craigslist.org/about/safety">
#        safety tips
#       </a>
#       <li>
#        <a href="https://www.craigslist.org/about/prohibited">
#         prohibited items
#        </a>
#        <li>
#         <a href="https://www.craigslist.org/about/recalled_items">
#          product recalls
#         </a>
#         <li>
#          <a href="https://www.craigslist.org/about/scams">
#           avoiding scams
#          </a>
#         </li>
#        </li>
#       </li>
#      </li>
#     </ul>
#    </aside>
#    <div class="slidemessage">
#     <span class="fave">
#      <span class="star">
#      </span>
#      favorited
#     </span>
#     <span class="unfave">
#      <span class="star">
#      </span>
#      no longer favorited
#     </span>
#     <span class="hide">
#      <span class="trash">
#      </span>
#      hidden
#     </span>
#     <span class="unhide">
#      <span class="trash">
#      </span>
#      no longer hidden
#     </span>
#    </div>
#    <footer>
#     <ul class="clfooter">
#      <li>
#       © 2023
#       <span class="desktop">
#        craigslist
#       </span>
#       <span class="mobile">
#        CL
#       </span>
#      </li>
#      <li>
#       <a href="https://www.craigslist.org/about/help/">
#        help
#       </a>
#      </li>
#      <li>
#       <a href="https://www.craigslist.org/about/scams">
#        safety
#       </a>
#      </li>
#      <li class="desktop">
#       <a href="https://www.craigslist.org/about/privacy.policy">
#        privacy
#       </a>
#      </li>
#      <li class="desktop">
#       <a href="https://forums.craigslist.org/?forumID=8">
#        feedback
#       </a>
#      </li>
#      <li>
#       <a href="https://www.craigslist.org/about/terms.of.use">
#        terms
#       </a>
#      </li>
#      <li>
#       <a href="https://www.craigslist.org/about/">
#        about
#       </a>
#      </li>
#      <li>
#       <a href="https://www.craigslist.org/about/craigslist_app">
#        craigslist app
#       </a>
#      </li>
#      <li>
#       <a href="https://www.craigslist.org/about/craigslist_is_hiring">
#        cl is hiring
#       </a>
#      </li>
#      <li>
#       <a href="https://newjersey.craigslist.org/sitemap.html">
#        sitemap
#       </a>
#      </li>
#     </ul>
#    </footer>
#   </section>
#   <template id="gallerycarousel">
#    <div class="slider-info">
#    </div>
#    <div class="slider-back arrow">
#     ‹
#    </div>
#    <div class="slider-forward arrow">
#     ›
#    </div>
#   </template>
#   <script id="clustertemplate" type="text/template">
#    <li class="posting {visited}" data-pid="{PostingID}">
#         <img src="{ImageThumb}">
#         <div class="housing_bubble_banner">
#             <span class="{hasPrice}price">{currencySymbol}{price}</span>
#             <span class="bedrooms">{BedroomsContent}</span>
#             <span class="postingtitle"><a>{PostingTitle}</a></span>
#             <span class="js-only map-banish-unbanish" data-pid="{PostingID}">
#                 <span class="banish">
#                     <span class="icon icon-trash" role="button"></span>
#                     <span class="screen-reader-text">hide this posting</span>
#                 </span>
#                 <span class="unbanish">
#                     <span class="icon icon-trash red" role="button"></span>
#                     unhide
#                 </span>
#             </span>
#         </div>
#     </li>
#   </script>
#   <script id="postingtemplate" type="text/template">
#    <div class="viewcontainer pics loading">
#         <div class="backtolist">
#             &laquo; back to posting list
#         </div>
#         <div class="title">
#             <span class="icon icon-star" data-pid="{PostingID}" role="button">
#                 <span class="screen-reader-text">favorite this post</span>
#             </span>
#             <span class="postingtitle">
#                 <a href="{PostingURL}" target="_blank">{PostingTitle}</a>
#             </span>
#             <div>
#                 <span class="{hasPrice}price">{currencySymbol}{price}</span>
#                 <span class="bedrooms">{BedroomsContent}</span>
#                 <span class="js-only map-banish-unbanish" data-pid="{PostingID}">
#                     <span class="banish">
#                         <span class="icon icon-trash" role="button"></span>
#                         <span class="screen-reader-text">hide this posting</span>
#                     </span>
#                     <span class="unbanish">
#                         <span class="icon icon-trash red" role="button"></span>
#                         <span class="screen-reader-text">unhide</span>
#                         unhide
#                     </span>
#                 </span>
#             </div>
#         </div>
#         <hr style="clear:both">
#         <div class="picscontainer gallery">
#             <span class="slider-back arrow">&lsaquo;</span><span class="slider-info"></span><span class="slider-forward arrow">&rsaquo;</span>
#             <div class="swipe">
#                 <div class="swipe-wrap">
#                     <img class="loading" src="//www.craigslist.org/images/animated-spinny.gif" alt="">
#                 </div>
#             </div>
#         </div>
#         <div class="infocontainer"></div>
#         <hr style="clear:both">
#         <div class="timecontainer"></div>
#         <a class="viewpostinglink" href="{PostingURL}" target="_blank">view posting</a>
#         <div class="contenttoggle">
#             <a class="moreinfo">more info</a>
#             <a class="showpics">show images</a>
#         </div>
#     </div>
#   </script>
#   <script id="popuptemplate" type="text/template">
#    <div id="mapbubble" class="posting">
#         <ul id="clusterbubble"></ul>
#         <div id="postbubble"></div>
#     </div>
#   </script>
#   <div id="curtain">
#    <div class="cover">
#    </div>
#    <div class="content">
#     <div class="icom-">
#     </div>
#     <div class="text loading">
#      loading
#     </div>
#     <div class="text reading">
#      reading
#     </div>
#     <div class="text writing">
#      writing
#     </div>
#     <div class="text saving">
#      saving
#     </div>
#     <div class="text searching">
#      searching
#     </div>
#     <div class="text message" id="curtainText">
#     </div>
#     <div class="text unrecoverable">
#      <p>
#       <a href="#" id="cl-unrecoverable-hard-refresh" onclick="location.reload(true);">
#        refresh the page.
#       </a>
#      </p>
#     </div>
#    </div>
#   </div>
#   <noscript id="no-js">
#    <div>
#     <h1>
#      north jersey for sale "guitar" - craigslist
#     </h1>
#     <p>
#      north jersey for sale "guitar" - craigslist
#     </p>
#     <aside class="error-message">
#      <p>
#       We've detected that JavaScript is not enabled in your browser. You must enable JavaScript to use craigslist.
#      </p>
#     </aside>
#    </div>
#   </noscript>
#  </body>
# </html>

# %%
# results are returned as an iterable list
results = soup.find_all('li', class_="result-row")

# %%
# Loop through returned results
for result in results:
    # Error handling
    try:
        # Identify and return title of listing
        title = result.find('a', class_="result-title").text
        # Identify and return price of listing
        price = result.a.span.text
        # Identify and return link to listing
        link = result.a['href']

        # Print results only if title, price, and link are available
        if (title and price and link):
            print('-------------')
            print(title)
            print(price)
            print(link)
    except AttributeError as e:
        print(e)
# Out:
# -------------
